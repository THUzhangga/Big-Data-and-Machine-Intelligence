# %%
from mnist import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1225b2a058bf> in <module>()
# ----> 1 from mnist import *
#
# /Users/zhenchen/Desktop/TechX2017/ML-ipynb/mnist.py in <module>()
#      23 import theano.tensor as T
#      24
# ---> 25 import lasagne
#      26
#      27
#
# ModuleNotFoundError: No module named 'lasagne'

# %% [markdown]
# # CNN MNIST
# ## Digit recognizer using Convolutional Neural Network

# %% [markdown]
# Training result with 500 EPOCH

# %%
main(model='cnn')
# Out:
# Loading data...
# Building model and compiling functions...
# Starting training...
# Epoch 1 of 500 took 3.008s
#   training loss:		1.669758
#   validation loss:		0.375276
#   validation accuracy:		89.84 %
# Epoch 2 of 500 took 2.980s
#   training loss:		0.526222
#   validation loss:		0.197731
#   validation accuracy:		94.40 %
# Epoch 3 of 500 took 2.976s
#   training loss:		0.357324
#   validation loss:		0.143127
#   validation accuracy:		95.77 %
# Epoch 4 of 500 took 2.977s
#   training loss:		0.289054
#   validation loss:		0.123029
#   validation accuracy:		96.27 %
# Epoch 5 of 500 took 2.983s
#   training loss:		0.246927
#   validation loss:		0.101032
#   validation accuracy:		96.98 %
# Epoch 6 of 500 took 2.973s
#   training loss:		0.218354
#   validation loss:		0.090231
#   validation accuracy:		97.37 %
# Epoch 7 of 500 took 2.979s
#   training loss:		0.200789
#   validation loss:		0.085459
#   validation accuracy:		97.46 %
# Epoch 8 of 500 took 2.982s
#   training loss:		0.184378
#   validation loss:		0.076693
#   validation accuracy:		97.74 %
# Epoch 9 of 500 took 2.986s
#   training loss:		0.170915
#   validation loss:		0.070766
#   validation accuracy:		97.95 %
# Epoch 10 of 500 took 2.985s
#   training loss:		0.165820
#   validation loss:		0.068950
#   validation accuracy:		98.03 %
# Epoch 11 of 500 took 2.981s
#   training loss:		0.154095
#   validation loss:		0.065038
#   validation accuracy:		98.16 %
# Epoch 12 of 500 took 2.980s
#   training loss:		0.146281
#   validation loss:		0.062968
#   validation accuracy:		98.22 %
# Epoch 13 of 500 took 2.986s
#   training loss:		0.140949
#   validation loss:		0.061597
#   validation accuracy:		98.35 %
# Epoch 14 of 500 took 2.966s
#   training loss:		0.134170
#   validation loss:		0.058965
#   validation accuracy:		98.40 %
# Epoch 15 of 500 took 2.964s
#   training loss:		0.126466
#   validation loss:		0.058126
#   validation accuracy:		98.41 %
# Epoch 16 of 500 took 2.982s
#   training loss:		0.124807
#   validation loss:		0.054198
#   validation accuracy:		98.43 %
# Epoch 17 of 500 took 2.984s
#   training loss:		0.122120
#   validation loss:		0.052254
#   validation accuracy:		98.54 %
# Epoch 18 of 500 took 2.984s
#   training loss:		0.116921
#   validation loss:		0.051453
#   validation accuracy:		98.52 %
# Epoch 19 of 500 took 2.975s
#   training loss:		0.113177
#   validation loss:		0.049795
#   validation accuracy:		98.55 %
# Epoch 20 of 500 took 2.957s
#   training loss:		0.111594
#   validation loss:		0.047947
#   validation accuracy:		98.61 %
# Epoch 21 of 500 took 2.969s
#   training loss:		0.106455
#   validation loss:		0.047038
#   validation accuracy:		98.65 %
# Epoch 22 of 500 took 2.980s
#   training loss:		0.102860
#   validation loss:		0.046829
#   validation accuracy:		98.64 %
# Epoch 23 of 500 took 2.976s
#   training loss:		0.102319
#   validation loss:		0.047385
#   validation accuracy:		98.68 %
# Epoch 24 of 500 took 2.979s
#   training loss:		0.098964
#   validation loss:		0.045191
#   validation accuracy:		98.71 %
# Epoch 25 of 500 took 2.983s
#   training loss:		0.096567
#   validation loss:		0.043565
#   validation accuracy:		98.72 %
# Epoch 26 of 500 took 2.984s
#   training loss:		0.093176
#   validation loss:		0.043312
#   validation accuracy:		98.74 %
# Epoch 27 of 500 took 2.974s
#   training loss:		0.093161
#   validation loss:		0.044481
#   validation accuracy:		98.68 %
# Epoch 28 of 500 took 2.975s
#   training loss:		0.091789
#   validation loss:		0.040876
#   validation accuracy:		98.86 %
# Epoch 29 of 500 took 2.978s
#   training loss:		0.087805
#   validation loss:		0.041006
#   validation accuracy:		98.81 %
# Epoch 30 of 500 took 2.977s
#   training loss:		0.087989
#   validation loss:		0.042480
#   validation accuracy:		98.78 %
# Epoch 31 of 500 took 2.974s
#   training loss:		0.084589
#   validation loss:		0.041911
#   validation accuracy:		98.81 %
# Epoch 32 of 500 took 2.979s
#   training loss:		0.083473
#   validation loss:		0.039466
#   validation accuracy:		98.86 %
# Epoch 33 of 500 took 2.973s
#   training loss:		0.079917
#   validation loss:		0.042454
#   validation accuracy:		98.82 %
# Epoch 34 of 500 took 2.951s
#   training loss:		0.079198
#   validation loss:		0.040336
#   validation accuracy:		98.88 %
# Epoch 35 of 500 took 2.972s
#   training loss:		0.075686
#   validation loss:		0.039949
#   validation accuracy:		98.84 %
# Epoch 36 of 500 took 2.976s
#   training loss:		0.074032
#   validation loss:		0.038038
#   validation accuracy:		98.91 %
# Epoch 37 of 500 took 2.977s
#   training loss:		0.077721
#   validation loss:		0.038354
#   validation accuracy:		98.89 %
# Epoch 38 of 500 took 2.979s
#   training loss:		0.076512
#   validation loss:		0.037728
#   validation accuracy:		98.93 %
# Epoch 39 of 500 took 2.980s
#   training loss:		0.074782
#   validation loss:		0.037865
#   validation accuracy:		98.87 %
# Epoch 40 of 500 took 2.981s
#   training loss:		0.072805
#   validation loss:		0.036198
#   validation accuracy:		98.94 %
# Epoch 41 of 500 took 2.978s
#   training loss:		0.071988
#   validation loss:		0.036813
#   validation accuracy:		98.97 %
# Epoch 42 of 500 took 2.979s
#   training loss:		0.071715
#   validation loss:		0.035435
#   validation accuracy:		98.96 %
# Epoch 43 of 500 took 2.975s
#   training loss:		0.067814
#   validation loss:		0.035235
#   validation accuracy:		99.04 %
# Epoch 44 of 500 took 2.980s
#   training loss:		0.069859
#   validation loss:		0.033884
#   validation accuracy:		99.05 %
# Epoch 45 of 500 took 2.979s
#   training loss:		0.066381
#   validation loss:		0.034252
#   validation accuracy:		98.97 %
# Epoch 46 of 500 took 2.981s
#   training loss:		0.067013
#   validation loss:		0.034829
#   validation accuracy:		98.95 %
# Epoch 47 of 500 took 2.977s
#   training loss:		0.066219
#   validation loss:		0.034280
#   validation accuracy:		99.05 %
# Epoch 48 of 500 took 2.979s
#   training loss:		0.065373
#   validation loss:		0.033494
#   validation accuracy:		99.05 %
# Epoch 49 of 500 took 2.977s
#   training loss:		0.065332
#   validation loss:		0.034519
#   validation accuracy:		99.04 %
# Epoch 50 of 500 took 2.979s
#   training loss:		0.063066
#   validation loss:		0.034162
#   validation accuracy:		98.99 %
# Epoch 51 of 500 took 2.992s
#   training loss:		0.063376
#   validation loss:		0.033085
#   validation accuracy:		99.07 %
# Epoch 52 of 500 took 2.979s
#   training loss:		0.063398
#   validation loss:		0.032325
#   validation accuracy:		99.06 %
# Epoch 53 of 500 took 2.966s
#   training loss:		0.059014
#   validation loss:		0.033889
#   validation accuracy:		99.03 %
# Epoch 54 of 500 took 2.955s
#   training loss:		0.060087
#   validation loss:		0.033645
#   validation accuracy:		98.99 %
# Epoch 55 of 500 took 2.982s
#   training loss:		0.059696
#   validation loss:		0.032660
#   validation accuracy:		99.04 %
# Epoch 56 of 500 took 2.981s
#   training loss:		0.061085
#   validation loss:		0.033037
#   validation accuracy:		99.05 %
# Epoch 57 of 500 took 2.980s
#   training loss:		0.058401
#   validation loss:		0.032202
#   validation accuracy:		99.07 %
# Epoch 58 of 500 took 2.979s
#   training loss:		0.056648
#   validation loss:		0.031543
#   validation accuracy:		99.15 %
# Epoch 59 of 500 took 2.982s
#   training loss:		0.057638
#   validation loss:		0.030585
#   validation accuracy:		99.17 %
# Epoch 60 of 500 took 2.983s
#   training loss:		0.057307
#   validation loss:		0.031782
#   validation accuracy:		99.07 %
# Epoch 61 of 500 took 2.974s
#   training loss:		0.056753
#   validation loss:		0.031217
#   validation accuracy:		99.15 %
# Epoch 62 of 500 took 2.981s
#   training loss:		0.056737
#   validation loss:		0.031225
#   validation accuracy:		99.12 %
# Epoch 63 of 500 took 2.979s
#   training loss:		0.055025
#   validation loss:		0.030800
#   validation accuracy:		99.08 %
# Epoch 64 of 500 took 2.983s
#   training loss:		0.053706
#   validation loss:		0.031668
#   validation accuracy:		99.03 %
# Epoch 65 of 500 took 2.981s
#   training loss:		0.054721
#   validation loss:		0.030901
#   validation accuracy:		99.13 %
# Epoch 66 of 500 took 2.987s
#   training loss:		0.055842
#   validation loss:		0.031897
#   validation accuracy:		99.10 %
# Epoch 67 of 500 took 2.977s
#   training loss:		0.053804
#   validation loss:		0.030739
#   validation accuracy:		99.13 %
# Epoch 68 of 500 took 2.980s
#   training loss:		0.052913
#   validation loss:		0.030310
#   validation accuracy:		99.17 %
# Epoch 69 of 500 took 2.976s
#   training loss:		0.052483
#   validation loss:		0.029514
#   validation accuracy:		99.13 %
# Epoch 70 of 500 took 2.987s
#   training loss:		0.053462
#   validation loss:		0.030139
#   validation accuracy:		99.17 %
# Epoch 71 of 500 took 2.983s
#   training loss:		0.052740
#   validation loss:		0.031282
#   validation accuracy:		99.11 %
# Epoch 72 of 500 took 2.979s
#   training loss:		0.052815
#   validation loss:		0.029651
#   validation accuracy:		99.10 %
# Epoch 73 of 500 took 2.976s
#   training loss:		0.050929
#   validation loss:		0.029540
#   validation accuracy:		99.21 %
# Epoch 74 of 500 took 2.980s
#   training loss:		0.054018
#   validation loss:		0.029266
#   validation accuracy:		99.15 %
# Epoch 75 of 500 took 2.972s
#   training loss:		0.049756
#   validation loss:		0.029290
#   validation accuracy:		99.15 %
# Epoch 76 of 500 took 2.979s
#   training loss:		0.050419
#   validation loss:		0.029827
#   validation accuracy:		99.12 %
# Epoch 77 of 500 took 2.983s
#   training loss:		0.050445
#   validation loss:		0.029756
#   validation accuracy:		99.16 %
# Epoch 78 of 500 took 2.977s
#   training loss:		0.048839
#   validation loss:		0.030226
#   validation accuracy:		99.13 %
# Epoch 79 of 500 took 2.984s
#   training loss:		0.047293
#   validation loss:		0.030139
#   validation accuracy:		99.21 %
# Epoch 80 of 500 took 2.975s
#   training loss:		0.046628
#   validation loss:		0.028715
#   validation accuracy:		99.27 %
# Epoch 81 of 500 took 2.976s
#   training loss:		0.048104
#   validation loss:		0.027905
#   validation accuracy:		99.25 %
# Epoch 82 of 500 took 2.968s
#   training loss:		0.047329
#   validation loss:		0.028641
#   validation accuracy:		99.16 %
# Epoch 83 of 500 took 2.980s
#   training loss:		0.047365
#   validation loss:		0.028209
#   validation accuracy:		99.21 %
# Epoch 84 of 500 took 2.952s
#   training loss:		0.045939
#   validation loss:		0.029040
#   validation accuracy:		99.17 %
# Epoch 85 of 500 took 2.963s
#   training loss:		0.044566
#   validation loss:		0.028085
#   validation accuracy:		99.26 %
# Epoch 86 of 500 took 2.979s
#   training loss:		0.046286
#   validation loss:		0.027409
#   validation accuracy:		99.27 %
# Epoch 87 of 500 took 2.975s
#   training loss:		0.046527
#   validation loss:		0.029202
#   validation accuracy:		99.19 %
# Epoch 88 of 500 took 2.970s
#   training loss:		0.043835
#   validation loss:		0.028037
#   validation accuracy:		99.26 %
# Epoch 89 of 500 took 2.952s
#   training loss:		0.045650
#   validation loss:		0.030064
#   validation accuracy:		99.15 %
# Epoch 90 of 500 took 2.954s
#   training loss:		0.044316
#   validation loss:		0.026993
#   validation accuracy:		99.31 %
# Epoch 91 of 500 took 2.949s
#   training loss:		0.044684
#   validation loss:		0.027363
#   validation accuracy:		99.25 %
# Epoch 92 of 500 took 2.952s
#   training loss:		0.044382
#   validation loss:		0.028740
#   validation accuracy:		99.17 %
# Epoch 93 of 500 took 2.948s
#   training loss:		0.044186
#   validation loss:		0.027485
#   validation accuracy:		99.25 %
# Epoch 94 of 500 took 2.955s
#   training loss:		0.043943
#   validation loss:		0.027271
#   validation accuracy:		99.24 %
# Epoch 95 of 500 took 2.950s
#   training loss:		0.043596
#   validation loss:		0.027827
#   validation accuracy:		99.19 %
# Epoch 96 of 500 took 2.953s
#   training loss:		0.044377
#   validation loss:		0.028321
#   validation accuracy:		99.22 %
# Epoch 97 of 500 took 2.957s
#   training loss:		0.043647
#   validation loss:		0.027051
#   validation accuracy:		99.29 %
# Epoch 98 of 500 took 2.951s
#   training loss:		0.045597
#   validation loss:		0.026718
#   validation accuracy:		99.25 %
# Epoch 99 of 500 took 2.950s
#   training loss:		0.042908
#   validation loss:		0.026635
#   validation accuracy:		99.28 %
# Epoch 100 of 500 took 2.949s
#   training loss:		0.043048
#   validation loss:		0.027577
#   validation accuracy:		99.19 %
# Epoch 101 of 500 took 2.948s
#   training loss:		0.041154
#   validation loss:		0.028490
#   validation accuracy:		99.22 %
# Epoch 102 of 500 took 2.951s
#   training loss:		0.041642
#   validation loss:		0.026965
#   validation accuracy:		99.20 %
# Epoch 103 of 500 took 2.962s
#   training loss:		0.041692
#   validation loss:		0.027825
#   validation accuracy:		99.24 %
# Epoch 104 of 500 took 2.955s
#   training loss:		0.042379
#   validation loss:		0.026698
#   validation accuracy:		99.27 %
# Epoch 105 of 500 took 2.956s
#   training loss:		0.040436
#   validation loss:		0.026198
#   validation accuracy:		99.30 %
# Epoch 106 of 500 took 2.950s
#   training loss:		0.041478
#   validation loss:		0.025715
#   validation accuracy:		99.26 %
# Epoch 107 of 500 took 2.949s
#   training loss:		0.039727
#   validation loss:		0.027264
#   validation accuracy:		99.26 %
# Epoch 108 of 500 took 2.956s
#   training loss:		0.040864
#   validation loss:		0.027499
#   validation accuracy:		99.25 %
# Epoch 109 of 500 took 2.971s
#   training loss:		0.039133
#   validation loss:		0.026688
#   validation accuracy:		99.26 %
# Epoch 110 of 500 took 2.970s
#   training loss:		0.039493
#   validation loss:		0.027813
#   validation accuracy:		99.21 %
# Epoch 111 of 500 took 2.973s
#   training loss:		0.038406
#   validation loss:		0.026714
#   validation accuracy:		99.26 %
# Epoch 112 of 500 took 2.969s
#   training loss:		0.040021
#   validation loss:		0.025449
#   validation accuracy:		99.34 %
# Epoch 113 of 500 took 2.958s
#   training loss:		0.040716
#   validation loss:		0.026907
#   validation accuracy:		99.26 %
# Epoch 114 of 500 took 2.966s
#   training loss:		0.039494
#   validation loss:		0.027053
#   validation accuracy:		99.26 %
# Epoch 115 of 500 took 2.965s
#   training loss:		0.040106
#   validation loss:		0.025445
#   validation accuracy:		99.34 %
# Epoch 116 of 500 took 2.960s
#   training loss:		0.039236
#   validation loss:		0.025005
#   validation accuracy:		99.31 %
# Epoch 117 of 500 took 2.949s
#   training loss:		0.038544
#   validation loss:		0.025540
#   validation accuracy:		99.31 %
# Epoch 118 of 500 took 2.950s
#   training loss:		0.038708
#   validation loss:		0.026249
#   validation accuracy:		99.28 %
# Epoch 119 of 500 took 2.958s
#   training loss:		0.037322
#   validation loss:		0.026079
#   validation accuracy:		99.30 %
# Epoch 120 of 500 took 2.960s
#   training loss:		0.039158
#   validation loss:		0.025514
#   validation accuracy:		99.34 %
# Epoch 121 of 500 took 2.957s
#   training loss:		0.036614
#   validation loss:		0.025885
#   validation accuracy:		99.32 %
# Epoch 122 of 500 took 2.958s
#   training loss:		0.037928
#   validation loss:		0.025980
#   validation accuracy:		99.25 %
# Epoch 123 of 500 took 2.966s
#   training loss:		0.037963
#   validation loss:		0.025626
#   validation accuracy:		99.31 %
# Epoch 124 of 500 took 2.957s
#   training loss:		0.038795
#   validation loss:		0.025178
#   validation accuracy:		99.33 %
# Epoch 125 of 500 took 2.956s
#   training loss:		0.035617
#   validation loss:		0.027059
#   validation accuracy:		99.28 %
# Epoch 126 of 500 took 2.952s
#   training loss:		0.036953
#   validation loss:		0.025318
#   validation accuracy:		99.34 %
# Epoch 127 of 500 took 2.953s
#   training loss:		0.036891
#   validation loss:		0.025775
#   validation accuracy:		99.31 %
# Epoch 128 of 500 took 2.955s
#   training loss:		0.037370
#   validation loss:		0.026438
#   validation accuracy:		99.28 %
# Epoch 129 of 500 took 2.967s
#   training loss:		0.035329
#   validation loss:		0.025433
#   validation accuracy:		99.32 %
# Epoch 130 of 500 took 2.958s
#   training loss:		0.033931
#   validation loss:		0.028421
#   validation accuracy:		99.18 %
# Epoch 131 of 500 took 2.974s
#   training loss:		0.036568
#   validation loss:		0.024680
#   validation accuracy:		99.40 %
# Epoch 132 of 500 took 2.975s
#   training loss:		0.036252
#   validation loss:		0.024597
#   validation accuracy:		99.32 %
# Epoch 133 of 500 took 2.977s
#   training loss:		0.035678
#   validation loss:		0.025779
#   validation accuracy:		99.25 %
# Epoch 134 of 500 took 2.970s
#   training loss:		0.034608
#   validation loss:		0.025357
#   validation accuracy:		99.30 %
# Epoch 135 of 500 took 2.976s
#   training loss:		0.035122
#   validation loss:		0.025328
#   validation accuracy:		99.33 %
# Epoch 136 of 500 took 2.979s
#   training loss:		0.036519
#   validation loss:		0.025083
#   validation accuracy:		99.28 %
# Epoch 137 of 500 took 2.982s
#   training loss:		0.036546
#   validation loss:		0.024246
#   validation accuracy:		99.34 %
# Epoch 138 of 500 took 2.974s
#   training loss:		0.035164
#   validation loss:		0.024379
#   validation accuracy:		99.35 %
# Epoch 139 of 500 took 2.953s
#   training loss:		0.034311
#   validation loss:		0.025429
#   validation accuracy:		99.29 %
# Epoch 140 of 500 took 2.967s
#   training loss:		0.033919
#   validation loss:		0.025708
#   validation accuracy:		99.36 %
# Epoch 141 of 500 took 2.980s
#   training loss:		0.034512
#   validation loss:		0.025067
#   validation accuracy:		99.31 %
# Epoch 142 of 500 took 2.961s
#   training loss:		0.033967
#   validation loss:		0.025463
#   validation accuracy:		99.36 %
# Epoch 143 of 500 took 2.956s
#   training loss:		0.034300
#   validation loss:		0.025958
#   validation accuracy:		99.31 %
# Epoch 144 of 500 took 2.956s
#   training loss:		0.034341
#   validation loss:		0.024538
#   validation accuracy:		99.37 %
# Epoch 145 of 500 took 2.973s
#   training loss:		0.034117
#   validation loss:		0.023861
#   validation accuracy:		99.38 %
# Epoch 146 of 500 took 2.956s
#   training loss:		0.034298
#   validation loss:		0.024142
#   validation accuracy:		99.36 %
# Epoch 147 of 500 took 2.975s
#   training loss:		0.033993
#   validation loss:		0.025419
#   validation accuracy:		99.31 %
# Epoch 148 of 500 took 2.977s
#   training loss:		0.031624
#   validation loss:		0.024362
#   validation accuracy:		99.38 %
# Epoch 149 of 500 took 2.984s
#   training loss:		0.032837
#   validation loss:		0.025318
#   validation accuracy:		99.34 %
# Epoch 150 of 500 took 2.971s
#   training loss:		0.030746
#   validation loss:		0.026081
#   validation accuracy:		99.26 %
# Epoch 151 of 500 took 2.990s
#   training loss:		0.032992
#   validation loss:		0.025539
#   validation accuracy:		99.36 %
# Epoch 152 of 500 took 2.971s
#   training loss:		0.033852
#   validation loss:		0.025413
#   validation accuracy:		99.34 %
# Epoch 153 of 500 took 2.979s
#   training loss:		0.032274
#   validation loss:		0.024341
#   validation accuracy:		99.37 %
# Epoch 154 of 500 took 2.966s
#   training loss:		0.033144
#   validation loss:		0.024555
#   validation accuracy:		99.34 %
# Epoch 155 of 500 took 2.958s
#   training loss:		0.032646
#   validation loss:		0.026048
#   validation accuracy:		99.31 %
# Epoch 156 of 500 took 2.953s
#   training loss:		0.033443
#   validation loss:		0.024459
#   validation accuracy:		99.37 %
# Epoch 157 of 500 took 2.952s
#   training loss:		0.031184
#   validation loss:		0.025387
#   validation accuracy:		99.35 %
# Epoch 158 of 500 took 2.953s
#   training loss:		0.030758
#   validation loss:		0.024255
#   validation accuracy:		99.40 %
# Epoch 159 of 500 took 2.949s
#   training loss:		0.030169
#   validation loss:		0.024287
#   validation accuracy:		99.38 %
# Epoch 160 of 500 took 2.954s
#   training loss:		0.031862
#   validation loss:		0.023782
#   validation accuracy:		99.37 %
# Epoch 161 of 500 took 2.970s
#   training loss:		0.030224
#   validation loss:		0.024495
#   validation accuracy:		99.39 %
# Epoch 162 of 500 took 2.965s
#   training loss:		0.029626
#   validation loss:		0.024539
#   validation accuracy:		99.34 %
# Epoch 163 of 500 took 2.984s
#   training loss:		0.029936
#   validation loss:		0.024034
#   validation accuracy:		99.37 %
# Epoch 164 of 500 took 2.982s
#   training loss:		0.028989
#   validation loss:		0.024332
#   validation accuracy:		99.35 %
# Epoch 165 of 500 took 2.972s
#   training loss:		0.030611
#   validation loss:		0.023985
#   validation accuracy:		99.41 %
# Epoch 166 of 500 took 2.978s
#   training loss:		0.030875
#   validation loss:		0.023841
#   validation accuracy:		99.37 %
# Epoch 167 of 500 took 2.976s
#   training loss:		0.032212
#   validation loss:		0.025455
#   validation accuracy:		99.26 %
# Epoch 168 of 500 took 2.981s
#   training loss:		0.031287
#   validation loss:		0.025260
#   validation accuracy:		99.30 %
# Epoch 169 of 500 took 2.977s
#   training loss:		0.032387
#   validation loss:		0.024037
#   validation accuracy:		99.39 %
# Epoch 170 of 500 took 2.976s
#   training loss:		0.029508
#   validation loss:		0.023515
#   validation accuracy:		99.43 %
# Epoch 171 of 500 took 2.976s
#   training loss:		0.029744
#   validation loss:		0.024118
#   validation accuracy:		99.41 %
# Epoch 172 of 500 took 2.974s
#   training loss:		0.030217
#   validation loss:		0.023163
#   validation accuracy:		99.38 %
# Epoch 173 of 500 took 2.974s
#   training loss:		0.029836
#   validation loss:		0.023236
#   validation accuracy:		99.36 %
# Epoch 174 of 500 took 2.971s
#   training loss:		0.029664
#   validation loss:		0.024100
#   validation accuracy:		99.33 %
# Epoch 175 of 500 took 2.972s
#   training loss:		0.029191
#   validation loss:		0.023653
#   validation accuracy:		99.41 %
# Epoch 176 of 500 took 2.972s
#   training loss:		0.030453
#   validation loss:		0.024850
#   validation accuracy:		99.32 %
# Epoch 177 of 500 took 2.975s
#   training loss:		0.028295
#   validation loss:		0.023941
#   validation accuracy:		99.38 %
# Epoch 178 of 500 took 2.977s
#   training loss:		0.030963
#   validation loss:		0.025646
#   validation accuracy:		99.37 %
# Epoch 179 of 500 took 2.980s
#   training loss:		0.030591
#   validation loss:		0.023611
#   validation accuracy:		99.39 %
# Epoch 180 of 500 took 2.974s
#   training loss:		0.028801
#   validation loss:		0.023764
#   validation accuracy:		99.41 %
# Epoch 181 of 500 took 2.966s
#   training loss:		0.029609
#   validation loss:		0.023809
#   validation accuracy:		99.41 %
# Epoch 182 of 500 took 2.953s
#   training loss:		0.028748
#   validation loss:		0.023845
#   validation accuracy:		99.39 %
# Epoch 183 of 500 took 2.961s
#   training loss:		0.029478
#   validation loss:		0.022862
#   validation accuracy:		99.41 %
# Epoch 184 of 500 took 2.966s
#   training loss:		0.027949
#   validation loss:		0.023831
#   validation accuracy:		99.43 %
# Epoch 185 of 500 took 2.968s
#   training loss:		0.030344
#   validation loss:		0.022509
#   validation accuracy:		99.38 %
# Epoch 186 of 500 took 2.966s
#   training loss:		0.029256
#   validation loss:		0.024523
#   validation accuracy:		99.36 %
# Epoch 187 of 500 took 2.971s
#   training loss:		0.028357
#   validation loss:		0.023285
#   validation accuracy:		99.43 %
# Epoch 188 of 500 took 2.977s
#   training loss:		0.027611
#   validation loss:		0.024261
#   validation accuracy:		99.40 %
# Epoch 189 of 500 took 2.974s
#   training loss:		0.027199
#   validation loss:		0.023121
#   validation accuracy:		99.34 %
# Epoch 190 of 500 took 2.976s
#   training loss:		0.027601
#   validation loss:		0.022560
#   validation accuracy:		99.42 %
# Epoch 191 of 500 took 2.974s
#   training loss:		0.027579
#   validation loss:		0.023554
#   validation accuracy:		99.40 %
# Epoch 192 of 500 took 2.975s
#   training loss:		0.027645
#   validation loss:		0.024147
#   validation accuracy:		99.36 %
# Epoch 193 of 500 took 2.975s
#   training loss:		0.027078
#   validation loss:		0.024563
#   validation accuracy:		99.40 %
# Epoch 194 of 500 took 2.974s
#   training loss:		0.028883
#   validation loss:		0.023700
#   validation accuracy:		99.38 %
# Epoch 195 of 500 took 2.974s
#   training loss:		0.027927
#   validation loss:		0.024785
#   validation accuracy:		99.40 %
# Epoch 196 of 500 took 2.968s
#   training loss:		0.026589
#   validation loss:		0.023866
#   validation accuracy:		99.36 %
# Epoch 197 of 500 took 2.973s
#   training loss:		0.027005
#   validation loss:		0.024473
#   validation accuracy:		99.38 %
# Epoch 198 of 500 took 2.970s
#   training loss:		0.026611
#   validation loss:		0.023942
#   validation accuracy:		99.40 %
# Epoch 199 of 500 took 2.973s
#   training loss:		0.026746
#   validation loss:		0.023411
#   validation accuracy:		99.44 %
# Epoch 200 of 500 took 2.975s
#   training loss:		0.026996
#   validation loss:		0.025384
#   validation accuracy:		99.37 %
# Epoch 201 of 500 took 2.978s
#   training loss:		0.026381
#   validation loss:		0.024755
#   validation accuracy:		99.32 %
# Epoch 202 of 500 took 2.976s
#   training loss:		0.026772
#   validation loss:		0.023864
#   validation accuracy:		99.38 %
# Epoch 203 of 500 took 2.975s
#   training loss:		0.026043
#   validation loss:		0.025332
#   validation accuracy:		99.38 %
# Epoch 204 of 500 took 2.976s
#   training loss:		0.027602
#   validation loss:		0.024618
#   validation accuracy:		99.37 %
# Epoch 205 of 500 took 2.952s
#   training loss:		0.025558
#   validation loss:		0.023818
#   validation accuracy:		99.41 %
# Epoch 206 of 500 took 2.967s
#   training loss:		0.026418
#   validation loss:		0.023336
#   validation accuracy:		99.42 %
# Epoch 207 of 500 took 2.977s
#   training loss:		0.025139
#   validation loss:		0.023527
#   validation accuracy:		99.41 %
# Epoch 208 of 500 took 2.971s
#   training loss:		0.025773
#   validation loss:		0.024702
#   validation accuracy:		99.38 %
# Epoch 209 of 500 took 2.955s
#   training loss:		0.027981
#   validation loss:		0.023307
#   validation accuracy:		99.36 %
# Epoch 210 of 500 took 2.950s
#   training loss:		0.026803
#   validation loss:		0.023481
#   validation accuracy:		99.44 %
# Epoch 211 of 500 took 2.953s
#   training loss:		0.025991
#   validation loss:		0.023363
#   validation accuracy:		99.40 %
# Epoch 212 of 500 took 2.953s
#   training loss:		0.026079
#   validation loss:		0.023393
#   validation accuracy:		99.40 %
# Epoch 213 of 500 took 2.949s
#   training loss:		0.025135
#   validation loss:		0.024262
#   validation accuracy:		99.38 %
# Epoch 214 of 500 took 2.948s
#   training loss:		0.024979
#   validation loss:		0.023665
#   validation accuracy:		99.44 %
# Epoch 215 of 500 took 2.955s
#   training loss:		0.027330
#   validation loss:		0.022993
#   validation accuracy:		99.37 %
# Epoch 216 of 500 took 2.955s
#   training loss:		0.024414
#   validation loss:		0.022343
#   validation accuracy:		99.43 %
# Epoch 217 of 500 took 2.952s
#   training loss:		0.025042
#   validation loss:		0.024185
#   validation accuracy:		99.39 %
# Epoch 218 of 500 took 2.950s
#   training loss:		0.023912
#   validation loss:		0.022910
#   validation accuracy:		99.46 %
# Epoch 219 of 500 took 2.952s
#   training loss:		0.026429
#   validation loss:		0.024227
#   validation accuracy:		99.42 %
# Epoch 220 of 500 took 2.973s
#   training loss:		0.023760
#   validation loss:		0.022326
#   validation accuracy:		99.46 %
# Epoch 221 of 500 took 2.980s
#   training loss:		0.025281
#   validation loss:		0.023140
#   validation accuracy:		99.43 %
# Epoch 222 of 500 took 2.977s
#   training loss:		0.025209
#   validation loss:		0.023759
#   validation accuracy:		99.41 %
# Epoch 223 of 500 took 2.979s
#   training loss:		0.023749
#   validation loss:		0.022234
#   validation accuracy:		99.45 %
# Epoch 224 of 500 took 2.980s
#   training loss:		0.026193
#   validation loss:		0.023475
#   validation accuracy:		99.37 %
# Epoch 225 of 500 took 2.979s
#   training loss:		0.025518
#   validation loss:		0.023350
#   validation accuracy:		99.42 %
# Epoch 226 of 500 took 2.974s
#   training loss:		0.026081
#   validation loss:		0.022081
#   validation accuracy:		99.44 %
# Epoch 227 of 500 took 2.980s
#   training loss:		0.025731
#   validation loss:		0.022236
#   validation accuracy:		99.42 %
# Epoch 228 of 500 took 2.977s
#   training loss:		0.025198
#   validation loss:		0.022193
#   validation accuracy:		99.42 %
# Epoch 229 of 500 took 2.982s
#   training loss:		0.024265
#   validation loss:		0.023148
#   validation accuracy:		99.43 %
# Epoch 230 of 500 took 2.975s
#   training loss:		0.024209
#   validation loss:		0.022691
#   validation accuracy:		99.43 %
# Epoch 231 of 500 took 2.975s
#   training loss:		0.024812
#   validation loss:		0.023743
#   validation accuracy:		99.42 %
# Epoch 232 of 500 took 2.952s
#   training loss:		0.024581
#   validation loss:		0.022960
#   validation accuracy:		99.42 %
# Epoch 233 of 500 took 2.947s
#   training loss:		0.024590
#   validation loss:		0.023372
#   validation accuracy:		99.43 %
# Epoch 234 of 500 took 2.949s
#   training loss:		0.023813
#   validation loss:		0.023674
#   validation accuracy:		99.42 %
# Epoch 235 of 500 took 2.948s
#   training loss:		0.024363
#   validation loss:		0.022404
#   validation accuracy:		99.43 %
# Epoch 236 of 500 took 2.975s
#   training loss:		0.022984
#   validation loss:		0.023032
#   validation accuracy:		99.43 %
# Epoch 237 of 500 took 2.978s
#   training loss:		0.025401
#   validation loss:		0.022666
#   validation accuracy:		99.45 %
# Epoch 238 of 500 took 2.975s
#   training loss:		0.024093
#   validation loss:		0.023099
#   validation accuracy:		99.42 %
# Epoch 239 of 500 took 2.974s
#   training loss:		0.024841
#   validation loss:		0.022642
#   validation accuracy:		99.43 %
# Epoch 240 of 500 took 2.971s
#   training loss:		0.023914
#   validation loss:		0.023003
#   validation accuracy:		99.43 %
# Epoch 241 of 500 took 2.976s
#   training loss:		0.023555
#   validation loss:		0.023623
#   validation accuracy:		99.35 %
# Epoch 242 of 500 took 2.977s
#   training loss:		0.022591
#   validation loss:		0.022632
#   validation accuracy:		99.44 %
# Epoch 243 of 500 took 2.978s
#   training loss:		0.023557
#   validation loss:		0.024628
#   validation accuracy:		99.36 %
# Epoch 244 of 500 took 2.979s
#   training loss:		0.023781
#   validation loss:		0.022278
#   validation accuracy:		99.46 %
# Epoch 245 of 500 took 3.000s
#   training loss:		0.023554
#   validation loss:		0.021807
#   validation accuracy:		99.43 %
# Epoch 246 of 500 took 2.978s
#   training loss:		0.025364
#   validation loss:		0.023525
#   validation accuracy:		99.40 %
# Epoch 247 of 500 took 2.977s
#   training loss:		0.024266
#   validation loss:		0.021578
#   validation accuracy:		99.44 %
# Epoch 248 of 500 took 2.979s
#   training loss:		0.025147
#   validation loss:		0.021780
#   validation accuracy:		99.41 %
# Epoch 249 of 500 took 2.979s
#   training loss:		0.022706
#   validation loss:		0.023701
#   validation accuracy:		99.33 %
# Epoch 250 of 500 took 2.983s
#   training loss:		0.021426
#   validation loss:		0.024343
#   validation accuracy:		99.39 %
# Epoch 251 of 500 took 2.979s
#   training loss:		0.023746
#   validation loss:		0.022579
#   validation accuracy:		99.42 %
# Epoch 252 of 500 took 2.981s
#   training loss:		0.021911
#   validation loss:		0.023391
#   validation accuracy:		99.39 %
# Epoch 253 of 500 took 2.982s
#   training loss:		0.021472
#   validation loss:		0.023973
#   validation accuracy:		99.40 %
# Epoch 254 of 500 took 2.992s
#   training loss:		0.023609
#   validation loss:		0.022996
#   validation accuracy:		99.41 %
# Epoch 255 of 500 took 2.988s
#   training loss:		0.022444
#   validation loss:		0.023789
#   validation accuracy:		99.40 %
# Epoch 256 of 500 took 3.014s
#   training loss:		0.022749
#   validation loss:		0.023652
#   validation accuracy:		99.40 %
# Epoch 257 of 500 took 2.979s
#   training loss:		0.021815
#   validation loss:		0.022558
#   validation accuracy:		99.43 %
# Epoch 258 of 500 took 2.980s
#   training loss:		0.022509
#   validation loss:		0.022710
#   validation accuracy:		99.42 %
# Epoch 259 of 500 took 2.987s
#   training loss:		0.022591
#   validation loss:		0.024502
#   validation accuracy:		99.35 %
# Epoch 260 of 500 took 2.978s
#   training loss:		0.024069
#   validation loss:		0.024254
#   validation accuracy:		99.33 %
# Epoch 261 of 500 took 2.979s
#   training loss:		0.022204
#   validation loss:		0.022997
#   validation accuracy:		99.43 %
# Epoch 262 of 500 took 2.986s
#   training loss:		0.022486
#   validation loss:		0.023986
#   validation accuracy:		99.39 %
# Epoch 263 of 500 took 2.970s
#   training loss:		0.021257
#   validation loss:		0.024331
#   validation accuracy:		99.39 %
# Epoch 264 of 500 took 2.991s
#   training loss:		0.021611
#   validation loss:		0.023227
#   validation accuracy:		99.39 %
# Epoch 265 of 500 took 2.992s
#   training loss:		0.022207
#   validation loss:		0.022378
#   validation accuracy:		99.43 %
# Epoch 266 of 500 took 2.986s
#   training loss:		0.021752
#   validation loss:		0.023279
#   validation accuracy:		99.43 %
# Epoch 267 of 500 took 2.986s
#   training loss:		0.021463
#   validation loss:		0.023563
#   validation accuracy:		99.39 %
# Epoch 268 of 500 took 2.987s
#   training loss:		0.021250
#   validation loss:		0.024203
#   validation accuracy:		99.40 %
# Epoch 269 of 500 took 2.987s
#   training loss:		0.022733
#   validation loss:		0.023538
#   validation accuracy:		99.39 %
# Epoch 270 of 500 took 2.977s
#   training loss:		0.021023
#   validation loss:		0.023202
#   validation accuracy:		99.41 %
# Epoch 271 of 500 took 2.978s
#   training loss:		0.021176
#   validation loss:		0.023323
#   validation accuracy:		99.40 %
# Epoch 272 of 500 took 2.981s
#   training loss:		0.020037
#   validation loss:		0.024402
#   validation accuracy:		99.38 %
# Epoch 273 of 500 took 2.980s
#   training loss:		0.021794
#   validation loss:		0.023677
#   validation accuracy:		99.39 %
# Epoch 274 of 500 took 2.979s
#   training loss:		0.021768
#   validation loss:		0.024068
#   validation accuracy:		99.35 %
# Epoch 275 of 500 took 2.971s
#   training loss:		0.021307
#   validation loss:		0.022894
#   validation accuracy:		99.41 %
# Epoch 276 of 500 took 2.974s
#   training loss:		0.020573
#   validation loss:		0.023128
#   validation accuracy:		99.45 %
# Epoch 277 of 500 took 2.980s
#   training loss:		0.022593
#   validation loss:		0.022349
#   validation accuracy:		99.39 %
# Epoch 278 of 500 took 2.981s
#   training loss:		0.022422
#   validation loss:		0.022301
#   validation accuracy:		99.43 %
# Epoch 279 of 500 took 2.974s
#   training loss:		0.019058
#   validation loss:		0.023132
#   validation accuracy:		99.45 %
# Epoch 280 of 500 took 2.971s
#   training loss:		0.021102
#   validation loss:		0.023103
#   validation accuracy:		99.38 %
# Epoch 281 of 500 took 2.975s
#   training loss:		0.022578
#   validation loss:		0.021847
#   validation accuracy:		99.44 %
# Epoch 282 of 500 took 2.973s
#   training loss:		0.020447
#   validation loss:		0.022165
#   validation accuracy:		99.46 %
# Epoch 283 of 500 took 2.973s
#   training loss:		0.021158
#   validation loss:		0.023789
#   validation accuracy:		99.37 %
# Epoch 284 of 500 took 2.967s
#   training loss:		0.020498
#   validation loss:		0.023117
#   validation accuracy:		99.39 %
# Epoch 285 of 500 took 2.972s
#   training loss:		0.020877
#   validation loss:		0.024112
#   validation accuracy:		99.36 %
# Epoch 286 of 500 took 2.975s
#   training loss:		0.020591
#   validation loss:		0.023304
#   validation accuracy:		99.41 %
# Epoch 287 of 500 took 2.975s
#   training loss:		0.021058
#   validation loss:		0.022457
#   validation accuracy:		99.39 %
# Epoch 288 of 500 took 2.975s
#   training loss:		0.020445
#   validation loss:		0.022778
#   validation accuracy:		99.39 %
# Epoch 289 of 500 took 2.977s
#   training loss:		0.020405
#   validation loss:		0.022412
#   validation accuracy:		99.46 %
# Epoch 290 of 500 took 2.975s
#   training loss:		0.020528
#   validation loss:		0.024728
#   validation accuracy:		99.36 %
# Epoch 291 of 500 took 2.976s
#   training loss:		0.022567
#   validation loss:		0.023345
#   validation accuracy:		99.39 %
# Epoch 292 of 500 took 2.971s
#   training loss:		0.020533
#   validation loss:		0.022688
#   validation accuracy:		99.42 %
# Epoch 293 of 500 took 2.971s
#   training loss:		0.019952
#   validation loss:		0.024171
#   validation accuracy:		99.41 %
# Epoch 294 of 500 took 2.972s
#   training loss:		0.019544
#   validation loss:		0.022506
#   validation accuracy:		99.44 %
# Epoch 295 of 500 took 2.975s
#   training loss:		0.020256
#   validation loss:		0.023288
#   validation accuracy:		99.40 %
# Epoch 296 of 500 took 2.971s
#   training loss:		0.021163
#   validation loss:		0.023450
#   validation accuracy:		99.41 %
# Epoch 297 of 500 took 2.975s
#   training loss:		0.021414
#   validation loss:		0.023862
#   validation accuracy:		99.38 %
# Epoch 298 of 500 took 2.973s
#   training loss:		0.020915
#   validation loss:		0.022499
#   validation accuracy:		99.45 %
# Epoch 299 of 500 took 2.976s
#   training loss:		0.020051
#   validation loss:		0.023175
#   validation accuracy:		99.47 %
# Epoch 300 of 500 took 2.974s
#   training loss:		0.019753
#   validation loss:		0.023581
#   validation accuracy:		99.40 %
# Epoch 301 of 500 took 2.974s
#   training loss:		0.019257
#   validation loss:		0.023106
#   validation accuracy:		99.42 %
# Epoch 302 of 500 took 2.973s
#   training loss:		0.020028
#   validation loss:		0.022811
#   validation accuracy:		99.46 %
# Epoch 303 of 500 took 2.974s
#   training loss:		0.018914
#   validation loss:		0.022507
#   validation accuracy:		99.42 %
# Epoch 304 of 500 took 2.977s
#   training loss:		0.019623
#   validation loss:		0.023438
#   validation accuracy:		99.43 %
# Epoch 305 of 500 took 2.979s
#   training loss:		0.019432
#   validation loss:		0.024109
#   validation accuracy:		99.40 %
# Epoch 306 of 500 took 2.976s
#   training loss:		0.020249
#   validation loss:		0.023565
#   validation accuracy:		99.35 %
# Epoch 307 of 500 took 2.975s
#   training loss:		0.020918
#   validation loss:		0.023187
#   validation accuracy:		99.41 %
# Epoch 308 of 500 took 2.976s
#   training loss:		0.019327
#   validation loss:		0.022439
#   validation accuracy:		99.45 %
# Epoch 309 of 500 took 2.979s
#   training loss:		0.020286
#   validation loss:		0.022755
#   validation accuracy:		99.46 %
# Epoch 310 of 500 took 2.983s
#   training loss:		0.019738
#   validation loss:		0.023150
#   validation accuracy:		99.42 %
# Epoch 311 of 500 took 2.976s
#   training loss:		0.020163
#   validation loss:		0.022456
#   validation accuracy:		99.42 %
# Epoch 312 of 500 took 2.976s
#   training loss:		0.019857
#   validation loss:		0.021842
#   validation accuracy:		99.46 %
# Epoch 313 of 500 took 2.976s
#   training loss:		0.019893
#   validation loss:		0.023189
#   validation accuracy:		99.36 %
# Epoch 314 of 500 took 2.979s
#   training loss:		0.018558
#   validation loss:		0.022777
#   validation accuracy:		99.41 %
# Epoch 315 of 500 took 2.976s
#   training loss:		0.019624
#   validation loss:		0.022933
#   validation accuracy:		99.45 %
# Epoch 316 of 500 took 2.976s
#   training loss:		0.019330
#   validation loss:		0.023383
#   validation accuracy:		99.41 %
# Epoch 317 of 500 took 2.977s
#   training loss:		0.018824
#   validation loss:		0.023527
#   validation accuracy:		99.42 %
# Epoch 318 of 500 took 2.970s
#   training loss:		0.019139
#   validation loss:		0.022726
#   validation accuracy:		99.44 %
# Epoch 319 of 500 took 2.976s
#   training loss:		0.018336
#   validation loss:		0.023208
#   validation accuracy:		99.45 %
# Epoch 320 of 500 took 2.974s
#   training loss:		0.019337
#   validation loss:		0.022764
#   validation accuracy:		99.46 %
# Epoch 321 of 500 took 2.976s
#   training loss:		0.019645
#   validation loss:		0.023789
#   validation accuracy:		99.36 %
# Epoch 322 of 500 took 2.974s
#   training loss:		0.018302
#   validation loss:		0.023836
#   validation accuracy:		99.40 %
# Epoch 323 of 500 took 2.974s
#   training loss:		0.019144
#   validation loss:		0.024609
#   validation accuracy:		99.39 %
# Epoch 324 of 500 took 2.974s
#   training loss:		0.018451
#   validation loss:		0.023078
#   validation accuracy:		99.49 %
# Epoch 325 of 500 took 2.979s
#   training loss:		0.021257
#   validation loss:		0.023916
#   validation accuracy:		99.40 %
# Epoch 326 of 500 took 2.969s
#   training loss:		0.018429
#   validation loss:		0.024876
#   validation accuracy:		99.37 %
# Epoch 327 of 500 took 2.970s
#   training loss:		0.018826
#   validation loss:		0.024707
#   validation accuracy:		99.40 %
# Epoch 328 of 500 took 2.975s
#   training loss:		0.018207
#   validation loss:		0.022637
#   validation accuracy:		99.44 %
# Epoch 329 of 500 took 2.974s
#   training loss:		0.018651
#   validation loss:		0.022251
#   validation accuracy:		99.44 %
# Epoch 330 of 500 took 2.973s
#   training loss:		0.018869
#   validation loss:		0.024963
#   validation accuracy:		99.34 %
# Epoch 331 of 500 took 2.974s
#   training loss:		0.019440
#   validation loss:		0.022535
#   validation accuracy:		99.40 %
# Epoch 332 of 500 took 2.981s
#   training loss:		0.019001
#   validation loss:		0.023392
#   validation accuracy:		99.37 %
# Epoch 333 of 500 took 2.976s
#   training loss:		0.019124
#   validation loss:		0.022784
#   validation accuracy:		99.46 %
# Epoch 334 of 500 took 2.979s
#   training loss:		0.018366
#   validation loss:		0.022439
#   validation accuracy:		99.50 %
# Epoch 335 of 500 took 2.974s
#   training loss:		0.019166
#   validation loss:		0.023959
#   validation accuracy:		99.37 %
# Epoch 336 of 500 took 2.974s
#   training loss:		0.017800
#   validation loss:		0.024440
#   validation accuracy:		99.37 %
# Epoch 337 of 500 took 2.980s
#   training loss:		0.017269
#   validation loss:		0.023754
#   validation accuracy:		99.41 %
# Epoch 338 of 500 took 2.979s
#   training loss:		0.018022
#   validation loss:		0.023208
#   validation accuracy:		99.46 %
# Epoch 339 of 500 took 2.981s
#   training loss:		0.019017
#   validation loss:		0.023082
#   validation accuracy:		99.44 %
# Epoch 340 of 500 took 2.981s
#   training loss:		0.017748
#   validation loss:		0.023762
#   validation accuracy:		99.42 %
# Epoch 341 of 500 took 2.980s
#   training loss:		0.016323
#   validation loss:		0.023408
#   validation accuracy:		99.46 %
# Epoch 342 of 500 took 2.981s
#   training loss:		0.017479
#   validation loss:		0.023567
#   validation accuracy:		99.45 %
# Epoch 343 of 500 took 2.980s
#   training loss:		0.017005
#   validation loss:		0.023730
#   validation accuracy:		99.41 %
# Epoch 344 of 500 took 2.979s
#   training loss:		0.018311
#   validation loss:		0.023813
#   validation accuracy:		99.41 %
# Epoch 345 of 500 took 2.971s
#   training loss:		0.017916
#   validation loss:		0.023203
#   validation accuracy:		99.43 %
# Epoch 346 of 500 took 2.976s
#   training loss:		0.018120
#   validation loss:		0.024054
#   validation accuracy:		99.41 %
# Epoch 347 of 500 took 2.978s
#   training loss:		0.017485
#   validation loss:		0.022102
#   validation accuracy:		99.46 %
# Epoch 348 of 500 took 2.977s
#   training loss:		0.017903
#   validation loss:		0.022961
#   validation accuracy:		99.42 %
# Epoch 349 of 500 took 2.976s
#   training loss:		0.017691
#   validation loss:		0.023197
#   validation accuracy:		99.43 %
# Epoch 350 of 500 took 2.979s
#   training loss:		0.016844
#   validation loss:		0.022553
#   validation accuracy:		99.45 %
# Epoch 351 of 500 took 2.980s
#   training loss:		0.017626
#   validation loss:		0.022246
#   validation accuracy:		99.44 %
# Epoch 352 of 500 took 2.976s
#   training loss:		0.017182
#   validation loss:		0.022763
#   validation accuracy:		99.45 %
# Epoch 353 of 500 took 2.982s
#   training loss:		0.018392
#   validation loss:		0.023164
#   validation accuracy:		99.39 %
# Epoch 354 of 500 took 2.977s
#   training loss:		0.017085
#   validation loss:		0.023060
#   validation accuracy:		99.44 %
# Epoch 355 of 500 took 2.976s
#   training loss:		0.017258
#   validation loss:		0.022562
#   validation accuracy:		99.45 %
# Epoch 356 of 500 took 2.973s
#   training loss:		0.018415
#   validation loss:		0.023285
#   validation accuracy:		99.39 %
# Epoch 357 of 500 took 2.981s
#   training loss:		0.017846
#   validation loss:		0.022930
#   validation accuracy:		99.46 %
# Epoch 358 of 500 took 2.992s
#   training loss:		0.016707
#   validation loss:		0.022929
#   validation accuracy:		99.41 %
# Epoch 359 of 500 took 2.977s
#   training loss:		0.017780
#   validation loss:		0.025124
#   validation accuracy:		99.36 %
# Epoch 360 of 500 took 2.976s
#   training loss:		0.017022
#   validation loss:		0.024202
#   validation accuracy:		99.36 %
# Epoch 361 of 500 took 2.976s
#   training loss:		0.017379
#   validation loss:		0.023757
#   validation accuracy:		99.41 %
# Epoch 362 of 500 took 2.974s
#   training loss:		0.017229
#   validation loss:		0.023266
#   validation accuracy:		99.43 %
# Epoch 363 of 500 took 2.975s
#   training loss:		0.018596
#   validation loss:		0.023282
#   validation accuracy:		99.44 %
# Epoch 364 of 500 took 2.974s
#   training loss:		0.016904
#   validation loss:		0.021786
#   validation accuracy:		99.48 %
# Epoch 365 of 500 took 2.978s
#   training loss:		0.017954
#   validation loss:		0.022682
#   validation accuracy:		99.44 %
# Epoch 366 of 500 took 2.972s
#   training loss:		0.016431
#   validation loss:		0.023058
#   validation accuracy:		99.45 %
# Epoch 367 of 500 took 2.971s
#   training loss:		0.017746
#   validation loss:		0.022999
#   validation accuracy:		99.43 %
# Epoch 368 of 500 took 2.971s
#   training loss:		0.016797
#   validation loss:		0.023517
#   validation accuracy:		99.42 %
# Epoch 369 of 500 took 2.973s
#   training loss:		0.016735
#   validation loss:		0.024503
#   validation accuracy:		99.38 %
# Epoch 370 of 500 took 2.974s
#   training loss:		0.017252
#   validation loss:		0.023283
#   validation accuracy:		99.42 %
# Epoch 371 of 500 took 2.976s
#   training loss:		0.017680
#   validation loss:		0.023703
#   validation accuracy:		99.42 %
# Epoch 372 of 500 took 2.971s
#   training loss:		0.017001
#   validation loss:		0.022713
#   validation accuracy:		99.43 %
# Epoch 373 of 500 took 2.973s
#   training loss:		0.017282
#   validation loss:		0.024114
#   validation accuracy:		99.40 %
# Epoch 374 of 500 took 2.974s
#   training loss:		0.015486
#   validation loss:		0.022991
#   validation accuracy:		99.42 %
# Epoch 375 of 500 took 2.973s
#   training loss:		0.016643
#   validation loss:		0.023034
#   validation accuracy:		99.46 %
# Epoch 376 of 500 took 2.971s
#   training loss:		0.017288
#   validation loss:		0.022401
#   validation accuracy:		99.46 %
# Epoch 377 of 500 took 2.972s
#   training loss:		0.015876
#   validation loss:		0.022823
#   validation accuracy:		99.46 %
# Epoch 378 of 500 took 2.973s
#   training loss:		0.015343
#   validation loss:		0.022771
#   validation accuracy:		99.47 %
# Epoch 379 of 500 took 2.976s
#   training loss:		0.016445
#   validation loss:		0.022258
#   validation accuracy:		99.46 %
# Epoch 380 of 500 took 2.977s
#   training loss:		0.017550
#   validation loss:		0.022662
#   validation accuracy:		99.39 %
# Epoch 381 of 500 took 2.971s
#   training loss:		0.018066
#   validation loss:		0.022591
#   validation accuracy:		99.43 %
# Epoch 382 of 500 took 2.976s
#   training loss:		0.017331
#   validation loss:		0.023225
#   validation accuracy:		99.41 %
# Epoch 383 of 500 took 2.976s
#   training loss:		0.016343
#   validation loss:		0.024100
#   validation accuracy:		99.42 %
# Epoch 384 of 500 took 2.974s
#   training loss:		0.016468
#   validation loss:		0.022831
#   validation accuracy:		99.48 %
# Epoch 385 of 500 took 2.975s
#   training loss:		0.017031
#   validation loss:		0.022937
#   validation accuracy:		99.42 %
# Epoch 386 of 500 took 2.977s
#   training loss:		0.016414
#   validation loss:		0.022314
#   validation accuracy:		99.44 %
# Epoch 387 of 500 took 2.977s
#   training loss:		0.016069
#   validation loss:		0.022841
#   validation accuracy:		99.43 %
# Epoch 388 of 500 took 2.979s
#   training loss:		0.015428
#   validation loss:		0.021954
#   validation accuracy:		99.46 %
# Epoch 389 of 500 took 2.978s
#   training loss:		0.016280
#   validation loss:		0.022196
#   validation accuracy:		99.44 %
# Epoch 390 of 500 took 2.975s
#   training loss:		0.015609
#   validation loss:		0.022580
#   validation accuracy:		99.45 %
# Epoch 391 of 500 took 2.972s
#   training loss:		0.017708
#   validation loss:		0.023010
#   validation accuracy:		99.46 %
# Epoch 392 of 500 took 2.978s
#   training loss:		0.016385
#   validation loss:		0.022162
#   validation accuracy:		99.48 %
# Epoch 393 of 500 took 2.974s
#   training loss:		0.016313
#   validation loss:		0.023594
#   validation accuracy:		99.47 %
# Epoch 394 of 500 took 2.976s
#   training loss:		0.015559
#   validation loss:		0.022960
#   validation accuracy:		99.45 %
# Epoch 395 of 500 took 2.977s
#   training loss:		0.017036
#   validation loss:		0.023494
#   validation accuracy:		99.41 %
# Epoch 396 of 500 took 2.977s
#   training loss:		0.015999
#   validation loss:		0.022884
#   validation accuracy:		99.49 %
# Epoch 397 of 500 took 2.976s
#   training loss:		0.015929
#   validation loss:		0.022838
#   validation accuracy:		99.44 %
# Epoch 398 of 500 took 2.974s
#   training loss:		0.016136
#   validation loss:		0.022200
#   validation accuracy:		99.43 %
# Epoch 399 of 500 took 2.972s
#   training loss:		0.015036
#   validation loss:		0.022331
#   validation accuracy:		99.46 %
# Epoch 400 of 500 took 2.974s
#   training loss:		0.015248
#   validation loss:		0.023088
#   validation accuracy:		99.42 %
# Epoch 401 of 500 took 2.979s
#   training loss:		0.015145
#   validation loss:		0.022465
#   validation accuracy:		99.44 %
# Epoch 402 of 500 took 2.978s
#   training loss:		0.015982
#   validation loss:		0.022663
#   validation accuracy:		99.48 %
# Epoch 403 of 500 took 2.981s
#   training loss:		0.015560
#   validation loss:		0.022208
#   validation accuracy:		99.47 %
# Epoch 404 of 500 took 2.981s
#   training loss:		0.013468
#   validation loss:		0.022604
#   validation accuracy:		99.43 %
# Epoch 405 of 500 took 2.969s
#   training loss:		0.016295
#   validation loss:		0.023673
#   validation accuracy:		99.39 %
# Epoch 406 of 500 took 2.969s
#   training loss:		0.015837
#   validation loss:		0.023152
#   validation accuracy:		99.47 %
# Epoch 407 of 500 took 2.974s
#   training loss:		0.015543
#   validation loss:		0.023648
#   validation accuracy:		99.43 %
# Epoch 408 of 500 took 2.977s
#   training loss:		0.016278
#   validation loss:		0.023511
#   validation accuracy:		99.46 %
# Epoch 409 of 500 took 2.974s
#   training loss:		0.016272
#   validation loss:		0.024153
#   validation accuracy:		99.40 %
# Epoch 410 of 500 took 2.974s
#   training loss:		0.014630
#   validation loss:		0.024067
#   validation accuracy:		99.39 %
# Epoch 411 of 500 took 2.976s
#   training loss:		0.016211
#   validation loss:		0.022974
#   validation accuracy:		99.43 %
# Epoch 412 of 500 took 2.966s
#   training loss:		0.015376
#   validation loss:		0.022799
#   validation accuracy:		99.44 %
# Epoch 413 of 500 took 2.978s
#   training loss:		0.014465
#   validation loss:		0.023879
#   validation accuracy:		99.45 %
# Epoch 414 of 500 took 2.975s
#   training loss:		0.015374
#   validation loss:		0.024419
#   validation accuracy:		99.38 %
# Epoch 415 of 500 took 2.974s
#   training loss:		0.014038
#   validation loss:		0.023719
#   validation accuracy:		99.44 %
# Epoch 416 of 500 took 2.976s
#   training loss:		0.015832
#   validation loss:		0.023071
#   validation accuracy:		99.47 %
# Epoch 417 of 500 took 2.975s
#   training loss:		0.014320
#   validation loss:		0.023394
#   validation accuracy:		99.45 %
# Epoch 418 of 500 took 2.975s
#   training loss:		0.015567
#   validation loss:		0.024936
#   validation accuracy:		99.36 %
# Epoch 419 of 500 took 2.973s
#   training loss:		0.014896
#   validation loss:		0.023905
#   validation accuracy:		99.44 %
# Epoch 420 of 500 took 2.977s
#   training loss:		0.014732
#   validation loss:		0.023369
#   validation accuracy:		99.43 %
# Epoch 421 of 500 took 2.975s
#   training loss:		0.015209
#   validation loss:		0.022559
#   validation accuracy:		99.46 %
# Epoch 422 of 500 took 2.974s
#   training loss:		0.016032
#   validation loss:		0.023178
#   validation accuracy:		99.46 %
# Epoch 423 of 500 took 2.976s
#   training loss:		0.015946
#   validation loss:		0.021892
#   validation accuracy:		99.48 %
# Epoch 424 of 500 took 2.977s
#   training loss:		0.016547
#   validation loss:		0.022399
#   validation accuracy:		99.44 %
# Epoch 425 of 500 took 2.972s
#   training loss:		0.015364
#   validation loss:		0.022076
#   validation accuracy:		99.47 %
# Epoch 426 of 500 took 2.975s
#   training loss:		0.017242
#   validation loss:		0.022368
#   validation accuracy:		99.49 %
# Epoch 427 of 500 took 2.976s
#   training loss:		0.014669
#   validation loss:		0.023324
#   validation accuracy:		99.43 %
# Epoch 428 of 500 took 2.980s
#   training loss:		0.014065
#   validation loss:		0.023311
#   validation accuracy:		99.47 %
# Epoch 429 of 500 took 2.982s
#   training loss:		0.015239
#   validation loss:		0.023486
#   validation accuracy:		99.42 %
# Epoch 430 of 500 took 2.979s
#   training loss:		0.014676
#   validation loss:		0.024037
#   validation accuracy:		99.43 %
# Epoch 431 of 500 took 2.980s
#   training loss:		0.014656
#   validation loss:		0.024084
#   validation accuracy:		99.44 %
# Epoch 432 of 500 took 2.973s
#   training loss:		0.015031
#   validation loss:		0.023503
#   validation accuracy:		99.42 %
# Epoch 433 of 500 took 2.980s
#   training loss:		0.013687
#   validation loss:		0.022383
#   validation accuracy:		99.45 %
# Epoch 434 of 500 took 2.975s
#   training loss:		0.013961
#   validation loss:		0.023431
#   validation accuracy:		99.46 %
# Epoch 435 of 500 took 2.974s
#   training loss:		0.014346
#   validation loss:		0.022871
#   validation accuracy:		99.46 %
# Epoch 436 of 500 took 2.975s
#   training loss:		0.014260
#   validation loss:		0.023094
#   validation accuracy:		99.44 %
# Epoch 437 of 500 took 2.974s
#   training loss:		0.014358
#   validation loss:		0.023572
#   validation accuracy:		99.41 %
# Epoch 438 of 500 took 2.974s
#   training loss:		0.014994
#   validation loss:		0.023878
#   validation accuracy:		99.49 %
# Epoch 439 of 500 took 2.975s
#   training loss:		0.015064
#   validation loss:		0.023693
#   validation accuracy:		99.40 %
# Epoch 440 of 500 took 2.974s
#   training loss:		0.014352
#   validation loss:		0.023941
#   validation accuracy:		99.41 %
# Epoch 441 of 500 took 2.974s
#   training loss:		0.013679
#   validation loss:		0.023908
#   validation accuracy:		99.43 %
# Epoch 442 of 500 took 2.976s
#   training loss:		0.014380
#   validation loss:		0.023190
#   validation accuracy:		99.45 %
# Epoch 443 of 500 took 2.976s
#   training loss:		0.014868
#   validation loss:		0.023083
#   validation accuracy:		99.43 %
# Epoch 444 of 500 took 2.976s
#   training loss:		0.013792
#   validation loss:		0.024033
#   validation accuracy:		99.45 %
# Epoch 445 of 500 took 2.975s
#   training loss:		0.013759
#   validation loss:		0.023866
#   validation accuracy:		99.45 %
# Epoch 446 of 500 took 2.974s
#   training loss:		0.014537
#   validation loss:		0.023363
#   validation accuracy:		99.44 %
# Epoch 447 of 500 took 2.972s
#   training loss:		0.016824
#   validation loss:		0.022783
#   validation accuracy:		99.46 %
# Epoch 448 of 500 took 2.975s
#   training loss:		0.013725
#   validation loss:		0.021817
#   validation accuracy:		99.48 %
# Epoch 449 of 500 took 2.970s
#   training loss:		0.014284
#   validation loss:		0.022704
#   validation accuracy:		99.47 %
# Epoch 450 of 500 took 2.973s
#   training loss:		0.014164
#   validation loss:		0.023200
#   validation accuracy:		99.46 %
# Epoch 451 of 500 took 2.974s
#   training loss:		0.014502
#   validation loss:		0.022368
#   validation accuracy:		99.44 %
# Epoch 452 of 500 took 2.975s
#   training loss:		0.013917
#   validation loss:		0.022023
#   validation accuracy:		99.43 %
# Epoch 453 of 500 took 2.979s
#   training loss:		0.013250
#   validation loss:		0.023766
#   validation accuracy:		99.45 %
# Epoch 454 of 500 took 2.977s
#   training loss:		0.013935
#   validation loss:		0.023453
#   validation accuracy:		99.45 %
# Epoch 455 of 500 took 2.975s
#   training loss:		0.014378
#   validation loss:		0.022824
#   validation accuracy:		99.43 %
# Epoch 456 of 500 took 2.978s
#   training loss:		0.012814
#   validation loss:		0.023278
#   validation accuracy:		99.43 %
# Epoch 457 of 500 took 2.980s
#   training loss:		0.014980
#   validation loss:		0.022121
#   validation accuracy:		99.45 %
# Epoch 458 of 500 took 2.982s
#   training loss:		0.013580
#   validation loss:		0.022532
#   validation accuracy:		99.46 %
# Epoch 459 of 500 took 2.978s
#   training loss:		0.013743
#   validation loss:		0.023622
#   validation accuracy:		99.45 %
# Epoch 460 of 500 took 2.987s
#   training loss:		0.014645
#   validation loss:		0.023577
#   validation accuracy:		99.41 %
# Epoch 461 of 500 took 2.975s
#   training loss:		0.014108
#   validation loss:		0.023957
#   validation accuracy:		99.40 %
# Epoch 462 of 500 took 2.981s
#   training loss:		0.013800
#   validation loss:		0.023733
#   validation accuracy:		99.44 %
# Epoch 463 of 500 took 2.981s
#   training loss:		0.013511
#   validation loss:		0.023615
#   validation accuracy:		99.42 %
# Epoch 464 of 500 took 2.978s
#   training loss:		0.014972
#   validation loss:		0.023889
#   validation accuracy:		99.40 %
# Epoch 465 of 500 took 2.974s
#   training loss:		0.013578
#   validation loss:		0.023636
#   validation accuracy:		99.40 %
# Epoch 466 of 500 took 2.979s
#   training loss:		0.015821
#   validation loss:		0.023267
#   validation accuracy:		99.45 %
# Epoch 467 of 500 took 2.973s
#   training loss:		0.014050
#   validation loss:		0.023951
#   validation accuracy:		99.42 %
# Epoch 468 of 500 took 2.979s
#   training loss:		0.013761
#   validation loss:		0.023196
#   validation accuracy:		99.46 %
# Epoch 469 of 500 took 2.980s
#   training loss:		0.013814
#   validation loss:		0.021758
#   validation accuracy:		99.44 %
# Epoch 470 of 500 took 2.978s
#   training loss:		0.014168
#   validation loss:		0.023756
#   validation accuracy:		99.43 %
# Epoch 471 of 500 took 2.979s
#   training loss:		0.014975
#   validation loss:		0.022243
#   validation accuracy:		99.47 %
# Epoch 472 of 500 took 2.979s
#   training loss:		0.013967
#   validation loss:		0.023323
#   validation accuracy:		99.43 %
# Epoch 473 of 500 took 2.979s
#   training loss:		0.014019
#   validation loss:		0.023478
#   validation accuracy:		99.40 %
# Epoch 474 of 500 took 2.978s
#   training loss:		0.014792
#   validation loss:		0.023511
#   validation accuracy:		99.43 %
# Epoch 475 of 500 took 2.976s
#   training loss:		0.014017
#   validation loss:		0.022864
#   validation accuracy:		99.48 %
# Epoch 476 of 500 took 2.978s
#   training loss:		0.013725
#   validation loss:		0.023083
#   validation accuracy:		99.46 %
# Epoch 477 of 500 took 2.977s
#   training loss:		0.013209
#   validation loss:		0.023738
#   validation accuracy:		99.42 %
# Epoch 478 of 500 took 2.974s
#   training loss:		0.013068
#   validation loss:		0.022802
#   validation accuracy:		99.43 %
# Epoch 479 of 500 took 2.974s
#   training loss:		0.014040
#   validation loss:		0.022510
#   validation accuracy:		99.45 %
# Epoch 480 of 500 took 2.976s
#   training loss:		0.013999
#   validation loss:		0.023150
#   validation accuracy:		99.41 %
# Epoch 481 of 500 took 2.977s
#   training loss:		0.012247
#   validation loss:		0.023103
#   validation accuracy:		99.44 %
# Epoch 482 of 500 took 2.974s
#   training loss:		0.013752
#   validation loss:		0.023012
#   validation accuracy:		99.46 %
# Epoch 483 of 500 took 2.975s
#   training loss:		0.012598
#   validation loss:		0.023668
#   validation accuracy:		99.43 %
# Epoch 484 of 500 took 2.975s
#   training loss:		0.013680
#   validation loss:		0.024087
#   validation accuracy:		99.44 %
# Epoch 485 of 500 took 2.975s
#   training loss:		0.013796
#   validation loss:		0.022301
#   validation accuracy:		99.45 %
# Epoch 486 of 500 took 2.977s
#   training loss:		0.013869
#   validation loss:		0.023774
#   validation accuracy:		99.44 %
# Epoch 487 of 500 took 2.978s
#   training loss:		0.014643
#   validation loss:		0.024444
#   validation accuracy:		99.41 %
# Epoch 488 of 500 took 2.976s
#   training loss:		0.013874
#   validation loss:		0.023352
#   validation accuracy:		99.48 %
# Epoch 489 of 500 took 2.985s
#   training loss:		0.013726
#   validation loss:		0.023367
#   validation accuracy:		99.46 %
# Epoch 490 of 500 took 2.977s
#   training loss:		0.014222
#   validation loss:		0.023599
#   validation accuracy:		99.43 %
# Epoch 491 of 500 took 2.976s
#   training loss:		0.013751
#   validation loss:		0.023305
#   validation accuracy:		99.39 %
# Epoch 492 of 500 took 2.975s
#   training loss:		0.013860
#   validation loss:		0.022296
#   validation accuracy:		99.49 %
# Epoch 493 of 500 took 2.980s
#   training loss:		0.012876
#   validation loss:		0.023204
#   validation accuracy:		99.47 %
# Epoch 494 of 500 took 2.973s
#   training loss:		0.014278
#   validation loss:		0.024221
#   validation accuracy:		99.39 %
# Epoch 495 of 500 took 2.976s
#   training loss:		0.013630
#   validation loss:		0.022994
#   validation accuracy:		99.48 %
# Epoch 496 of 500 took 2.976s
#   training loss:		0.014338
#   validation loss:		0.022864
#   validation accuracy:		99.47 %
# Epoch 497 of 500 took 2.973s
#   training loss:		0.013496
#   validation loss:		0.023121
#   validation accuracy:		99.47 %
# Epoch 498 of 500 took 2.974s
#   training loss:		0.013878
#   validation loss:		0.023465
#   validation accuracy:		99.47 %
# Epoch 499 of 500 took 2.980s
#   training loss:		0.013472
#   validation loss:		0.025016
#   validation accuracy:		99.37 %
# Epoch 500 of 500 took 2.977s
#   training loss:		0.013529
#   validation loss:		0.022901
#   validation accuracy:		99.45 %
# Final results:
#   test loss:			0.014611
#   test accuracy:		99.56 %

# %% [markdown]
# Operation teardown

# %%
# We'll create a CNN of two convolution + pooling stages and a
# fully-connected hidden layer in front of the output layer.

# %%
# Load the dataset
print("Loading data...")
X_train, y_train, X_val, y_val, X_test, y_test = load_dataset()
print("Data loaded.")
# Out:
# Loading data...
# Data loaded.

# %%
# Prepare Theano variables for inputs and targets
input_var = T.tensor4('inputs')
target_var = T.ivector('targets')

# %%
# Input layer:
network = lasagne.layers.InputLayer(shape=(None, 1, 28, 28), 
                                    input_var=input_var)

# %%
# We do not apply input dropout, as it tends to work less well
# for convolutional layers.

# Convolutional layer with 32 kernels of size 5x5. Strided and padded
# convolutions are supported as well; see the docstring.
network = lasagne.layers.Conv2DLayer(
        network, num_filters=32, filter_size=(5, 5),
        nonlinearity=lasagne.nonlinearities.rectify,
        W=lasagne.init.GlorotUniform())

# %%
# Expert note: Lasagne provides alternative convolutional layers that
# override Theano's choice of which implementation to use; for details
# please see http://lasagne.readthedocs.org/en/latest/user/tutorial.html.

# Max-pooling layer of factor 2 in both dimensions:
network = lasagne.layers.MaxPool2DLayer(network, pool_size=(2, 2))

# %%
# Another convolution with 32 5x5 kernels, and another 2x2 pooling:
network = lasagne.layers.Conv2DLayer(
        network, num_filters=32, filter_size=(5, 5),
        nonlinearity=lasagne.nonlinearities.rectify)
network = lasagne.layers.MaxPool2DLayer(network, pool_size=(2, 2))

# %%
# A fully-connected layer of 256 units with 50% dropout on its inputs:
network = lasagne.layers.DenseLayer(
        lasagne.layers.dropout(network, p=.5),
        num_units=256,
        nonlinearity=lasagne.nonlinearities.rectify)

# %%
# And, finally, the 10-unit output layer with 50% dropout on its inputs:
network = lasagne.layers.DenseLayer(
        lasagne.layers.dropout(network, p=.5),
        num_units=10,
        nonlinearity=lasagne.nonlinearities.softmax)

# %%
# Create a loss expression for training, i.e., a scalar objective we want
# to minimize (for our multi-class problem, it is the cross-entropy loss):
prediction = lasagne.layers.get_output(network)
loss = lasagne.objectives.categorical_crossentropy(prediction, target_var)
loss = loss.mean()

# %%
# Create update expressions for training, i.e., how to modify the
# parameters at each training step. Here, we'll use Stochastic Gradient
# Descent (SGD) with Nesterov momentum, but Lasagne offers plenty more.
params = lasagne.layers.get_all_params(network, trainable=True)
updates = lasagne.updates.nesterov_momentum(
        loss, params, learning_rate=0.01, momentum=0.9)

# %%
# Create a loss expression for validation/testing. The crucial difference
# here is that we do a deterministic forward pass through the network,
# disabling dropout layers.
test_prediction = lasagne.layers.get_output(network, deterministic=True)
test_loss = lasagne.objectives.categorical_crossentropy(test_prediction,
                                                        target_var)
test_loss = test_loss.mean()
# As a bonus, also create an expression for the classification accuracy:
test_acc = T.mean(T.eq(T.argmax(test_prediction, axis=1), target_var),
                    dtype=theano.config.floatX)

# %%
# Compile a function performing a training step on a mini-batch (by giving
# the updates dictionary) and returning the corresponding training loss:
train_fn = theano.function([input_var, target_var], loss, updates=updates)

# Compile a second function computing the validation loss and accuracy:
val_fn = theano.function([input_var, target_var], [test_loss, test_acc])

# %% [markdown]
# ### Launch the training loop

# %%
# We iterate over epochs:
for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    train_err = 0
    train_batches = 0
    start_time = time.time()
    for batch in iterate_minibatches(X_train, y_train, 500, shuffle=True):
        inputs, targets = batch
        train_err += train_fn(inputs, targets)
        train_batches += 1

    # And a full pass over the validation data:
    val_err = 0
    val_acc = 0
    val_batches = 0
    for batch in iterate_minibatches(X_val, y_val, 500, shuffle=False):
        inputs, targets = batch
        err, acc = val_fn(inputs, targets)
        val_err += err
        val_acc += acc
        val_batches += 1

    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss:\t\t{:.6f}".format(train_err / train_batches))
    print("  validation loss:\t\t{:.6f}".format(val_err / val_batches))
    print("  validation accuracy:\t\t{:.2f} %".format(
        val_acc / val_batches * 100))

# After training, we compute and print the test error:
test_err = 0
test_acc = 0
test_batches = 0
for batch in iterate_minibatches(X_test, y_test, 500, shuffle=False):
    inputs, targets = batch
    err, acc = val_fn(inputs, targets)
    test_err += err
    test_acc += acc
    test_batches += 1
print("Final results:")
print("  test loss:\t\t\t{:.6f}".format(test_err / test_batches))
print("  test accuracy:\t\t{:.2f} %".format(
    test_acc / test_batches * 100))

# %% [markdown]
# ### Save the training results (optional)

# %%
# Optionally, you could now dump the network weights to a file like this:
np.savez('trained_model.npz', *lasagne.layers.get_all_param_values(network))
#
# And load them again later on like this:
# with np.load('model.npz') as f:
#     param_values = [f['arr_%d' % i] for i in range(len(f.files))]
# lasagne.layers.set_all_param_values(network, param_values)
